# %%
# !conv_mesh='/Users/theobourdais/miniconda3/envs/PDE/lib/python3.11/site-packages/sfepy/scripts/convert_mesh.py'
# !mesh='/Users/theobourdais/Desktop/mesh_1.mesh'
# !new_mesh='/Users/theobourdais/Desktop/mesh2D_1.mesh'

# !python $conv_mesh -2 $mesh $new_mesh

# %%
import meshio

m=meshio.read('/Users/theobourdais/Desktop/mesh2D_1.mesh')

# %%
m.points
# Out:
# array([[0.        , 0.        ],
#        [1.        , 1.        ],
#        [3.        , 0.        ],
#        [1.5       , 1.2       ],
#        [2.25      , 2.25      ],
#        [0.75      , 1.1       ],
#        [0.0056667 , 0.00831117],
#        [0.01171874, 0.01718749],
#        [0.01818233, 0.02666741],
#        [0.02508543, 0.03679197],
#        [0.03245796, 0.04760501],
#        [0.04033182, 0.05915333],
#        [0.0487411 , 0.07148695],
#        [0.05772222, 0.08465925],
#        [0.06731406, 0.09872729],
#        [0.07755815, 0.11375195],
#        [0.08849884, 0.12979829],
#        [0.1001835 , 0.1469358 ],
#        [0.11266272, 0.16523866],
#        [0.12599054, 0.18478612],
#        [0.14022465, 0.20566282],
#        [0.15542669, 0.22795915],
#        [0.17166247, 0.25177163],
#        [0.1890023 , 0.27720338],
#        [0.20752124, 0.30436449],
#        [0.22729948, 0.33337257],
#        [0.24842265, 0.36435321],
#        [0.27098219, 0.39744055],
# ...
