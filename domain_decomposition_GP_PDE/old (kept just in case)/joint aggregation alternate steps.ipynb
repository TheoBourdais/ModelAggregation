# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import pairwise_distances
from functools import partial
from mpl_toolkits.axes_grid1 import make_axes_locatable

from tqdm import tqdm
from PDE_solver_backend import Aggregate,PDESolver
from PDE_solver_backend_laplace import PDESolverLaplace
from random import shuffle

# %%
def make_points_inside(Nd,range_model=np.array([[-1,1],[-1,1]])):
    assert range_model.shape==(2,2) and np.all(range_model[:,1:]-range_model[:,:1]>=0)
    clipped=np.clip(range_model,-1,1)

    return (clipped[:,1:]-clipped[:,:1]).T*np.random.rand(Nd,2)+clipped[:,:1].T

def make_points_boundary(Nb):
    X=np.stack([2*np.random.rand(Nb)-1,2*np.random.randint(0,2,Nb)-1]).T
    list(map(np.random.shuffle, X))
    np.random.shuffle(X)
    return X

def make_points_line(N,which_axis,fixed_value,range_other,nugget=1e-5):
    assert which_axis in {'x','y'}
    X=np.zeros((N,2))
    num_axis=int(which_axis=='y')
    X[:,num_axis]=fixed_value
    X[:,1-num_axis]=np.linspace(range_other[0]+nugget,range_other[1]-nugget,N)
    return X

def make_points_on_specific_boundary(Nb,which_axis,which_side,range_model=np.array([-1,1])):
    assert which_axis in {'x','y'}
    assert which_side in {-1,1}
    assert range_model.shape==(2,) and range_model[1]-range_model[0]>=0
    X=np.zeros((Nb,2))
    num_axis=int(which_axis=='y')
    X[:,num_axis]=which_side
    X[:,1-num_axis]=np.random.rand(Nb)*(range_model[1]-range_model[0])+range_model[0]
    return X

def plot_vectorized_function(f,mesh_size=0.05):
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    x = y = np.arange(-1.0, 1.0, mesh_size)
    X, Y = np.meshgrid(x, y)
    Z=f(np.stack([X.flatten(),Y.flatten()],axis=-1)).reshape(X.shape)

    ax.plot_surface(X, Y, Z)

    ax.set_xlabel('x1')
    ax.set_ylabel('y1')
    return fig

def plot_function(f):
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    x = y = np.arange(-1.0, 1.0, 0.05)
    X, Y = np.meshgrid(x, y)
    zs = np.array([f([x,y]) for x,y in zip(np.ravel(X), np.ravel(Y))])
    Z = zs.reshape(X.shape)

    ax.plot_surface(X, Y, Z)

    ax.set_xlabel('x1')
    ax.set_ylabel('y1')
    return fig

def dumb_aggregate(x,models,width):
    modified=(x+1)/2*width
    indexes=modified.astype(np.int32)
    which_model=indexes[:,0]+width*indexes[:,1]
    res=np.zeros(x.shape[0])
    for i,model in enumerate(models):
        res[which_model==i]=model(x[which_model==i])
    return res

def laplacian_aggregate(x,models,width):
    modified=(x+1)/2*width
    indexes=modified.astype(np.int32)
    which_model=indexes[:,0]+width*indexes[:,1]
    res=np.zeros(x.shape[0])
    for i,model in enumerate(models):
        res[which_model==i]=model.laplacian(x[which_model==i])
    return res

# %%
from sympy import cos,sin,pi,symbols,diff,lambdify,exp

x,y = symbols('x,y')
#u_symbolic=(x**2-1)/(1-0.95*sin(4*pi*y))*sin(pi*y)
u_symbolic=exp(-x+y)*cos(pi*x*y)#cos(4*pi*x)*cos(pi/2*y)
laplacian=lambda f:diff(f,x,x)+diff(f,y,y)
f_symbolic=-laplacian(u_symbolic)+u_symbolic**3
#real_u=lambda x:np.cos(np.pi*x[0]/2)*np.cos(np.pi*x[1]/2)
real_u_tuple=lambdify((x,y),u_symbolic)
real_u=lambda xy:real_u_tuple(xy[0],xy[1])
#f=lambda x:real_u(x)*np.pi**2/2+(real_u(x))**3
f_tuple=lambdify((x,y),f_symbolic)
f=lambda xy:f_tuple(xy[0],xy[1])
#g=lambda x:0
tau=lambda x:np.power(x,3)
dtau=lambda x:3*x**2
#tau=lambda x:np.zeros_like(x)
#dtau=lambda x:np.zeros_like(x)
f_symbolic
# Out:
# -(-pi**2*x**2*cos(pi*x*y) - 2*pi*x*sin(pi*x*y) + cos(pi*x*y))*exp(-x + y) - (-pi**2*y**2*cos(pi*x*y) + 2*pi*y*sin(pi*x*y) + cos(pi*x*y))*exp(-x + y) + exp(-3*x + 3*y)*cos(pi*x*y)**3

# %%
dxu_tuple=lambdify((x,y),diff(u_symbolic,x))
dxu=lambda xy:dxu_tuple(xy[0],xy[1])
dyu_tuple=lambdify((x,y),diff(u_symbolic,y))
dyu=lambda xy:dyu_tuple(xy[0],xy[1])

# %%
int_point_number=2000
ext_point_number=1000
width=2
int_point_per_model=int_point_number//width**2
ext_point_per_model=ext_point_number//width**2

sigma=0.1
boundary_width=0

models=[]
laplace_models=[]
for i in range(width**2):
    ext_point_per_model=ext_point_number//width**2
    yi=i//width
    xi=i%width
    range_model=np.array([
        [-1+2*xi/width,-1+2*(xi+1)/width],
        [-1+2*yi/width,-1+2*(yi+1)/width]
    ])
    X_int=make_points_inside(int_point_per_model,range_model)
    X_bounds=[]
    if i%width==0:
        X_bounds.append(make_points_line(ext_point_per_model//4,'x',-1,[-1+2*yi/width,-1+2*(yi+1)/width]))
    if i%width==width-1:
        X_bounds.append(make_points_line(ext_point_per_model//4,'x',1,[-1+2*yi/width,-1+2*(yi+1)/width]))
    if i//width==0:
        X_bounds.append(make_points_line(ext_point_per_model//4,'y',-1,[-1+2*xi/width,-1+2*(xi+1)/width]))
    if i//width==width-1:
        X_bounds.append(make_points_line(ext_point_per_model//4,'y',1,[-1+2*xi/width,-1+2*(xi+1)/width]))

    plt.scatter(X_int[:,0],X_int[:,1],label=f'{i}',s=5)

    try:
        X_boundary=np.concatenate(X_bounds)
        plt.scatter(X_boundary[:,0],X_boundary[:,1],label=f'boundary {i}',s=5)
    except ValueError:
        X_boundary=np.empty((0,2))
    
    models.append(
        PDESolver(
            X_int=X_int,
            X_boundary=X_boundary,
            sigma=sigma,
            name=f'model {i}')
    )
    laplace_models.append(
        PDESolverLaplace(
            X_int=X_int,
            X_boundary=X_boundary,
            sigma=sigma,
            name=f'model laplace {i}')
    )
    #ext_point_per_model=4
    if i%width>0:
        range_neighbors=np.array([
            [-1+2*xi/width-boundary_width,-1+2*xi/width+boundary_width],
            [-1+2*yi/width,-1+2*(yi+1)/width]
        ])
        #X_shared=make_points_line(ext_point_per_model//4,'x',-1+2*xi/width,[-1+2*yi/width,-1+2*(yi+1)/width])
        X_shared=make_points_inside(ext_point_per_model//4,range_neighbors)
        models[-1].add_neighbors([models[-2]], [X_shared])
        models[-2].add_neighbors([models[-1]], [X_shared])
        laplace_models[-1].add_neighbors([laplace_models[-2]], [X_shared])
        laplace_models[-2].add_neighbors([laplace_models[-1]], [X_shared])
        plt.scatter(X_shared[:,0],X_shared[:,1],label=f'shared {models[-1]} {models[-2]}',s=5)
    if i//width>0:
        range_neighbors=np.array([
            [-1+2*xi/width,-1+2*(xi+1)/width],
            [-1+2*yi/width-boundary_width,-1+2*(yi)/width+boundary_width]
        ])
        X_shared=make_points_inside(ext_point_per_model//4,range_neighbors)
        #X_shared=make_points_line(ext_point_per_model//4,'y',-1+2*yi/width,[-1+2*xi/width,-1+2*(xi+1)/width])
        models[-1].add_neighbors([models[-1-width]], [X_shared])
        models[-1-width].add_neighbors([models[-1]], [X_shared])
        laplace_models[-1].add_neighbors([laplace_models[-1-width]], [X_shared])
        laplace_models[-1-width].add_neighbors([laplace_models[-1]], [X_shared])
        plt.scatter(X_shared[:,0],X_shared[:,1],label=f'shared {models[-1]} {models[-1-width]}',s=5)

plt.legend()
plt.show()

# %%
models[0].real_u=real_u
models[0].dx=dxu
models[0].dy=dyu

# %%
PDESolver.joint_fit(models,f,real_u,tau,dtau,tol=1e-6)
# Out:
# Current residual 2.805e-07: : 46it [00:12,  3.64it/s]

# %%
models[0].shared_value
# Out:
# {model 1: {'dirac': array([0.80251834]),
#   'dx': array([-0.80251834]),
#   'dy': array([0.80251834])},
#  model 2: {'dirac': array([1.516293]),
#   'dx': array([-1.516293]),
#   'dy': array([1.516293])}}

# %%
local_aggregate=partial(dumb_aggregate,models=models,width=width)
fig=plot_vectorized_function(local_aggregate,0.05)
plt.title('Numerical solution of the PDE')
plt.show()

# %%
local_laplacian=partial(laplacian_aggregate,models=models,width=width)
fig=plot_vectorized_function(local_laplacian,0.05)
plt.title('Numerical solution of the PDE')
plt.show()

# %%
for model in models:
    model.a = np.concatenate(
        [np.array([real_u(xy) for xy in model.X_shared[n]]) for n in model.neighbors]
        + [model.g_vec]
        + [np.array([real_u(xy) for xy in model.X_int])]
        + [np.array([dxu(xy) for xy in model.X_shared[n]]) for n in model.neighbors]
        + [np.array([dyu(xy) for xy in model.X_shared[n]]) for n in model.neighbors]
        + [model.f_vec-np.array([real_u(xy) for xy in model.X_int])**3]
    )
    model.coeff = model.K_inv @ model.a

# %%
local_aggregate=partial(dumb_aggregate,models=models,width=width)
fig=plot_vectorized_function(local_aggregate,0.05)
plt.title('Numerical solution of the PDE')
plt.show()

# %%
print(1/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /Users/theobourdais/Desktop/Caltech/Research/model_aggregation/ModelAggregation/joint aggregation alternate steps.ipynb Cellule 9 in 1
# ----> <a href='vscode-notebook-cell:/Users/theobourdais/Desktop/Caltech/Research/model_aggregation/ModelAggregation/joint%20aggregation%20alternate%20steps.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> print(1/0)
#
# ZeroDivisionError: division by zero

# %%
for model in models:
    model.fit_interior(f,real_u,tau,dtau,use_shared=False,nugget=1e-5)
PDESolver.joint_fit_boundaries(models)
local_aggregate=partial(dumb_aggregate,models=models,width=width)
fig=plot_vectorized_function(local_aggregate,0.05)
plt.title('Numerical solution of the PDE')
plt.show()
for i in tqdm(range(10)):
    indexes=[k for k in range(len(models))]
    shuffle(indexes)
    for j in indexes:
        models[j].fit_interior(f,real_u,tau,dtau,use_shared=True,nugget=1e-5)
    PDESolver.joint_fit_boundaries(models)
local_aggregate=partial(dumb_aggregate,models=models,width=width)
fig=plot_vectorized_function(local_aggregate,0.05)
plt.title('Numerical solution of the PDE')
plt.show()
# Out:
# Current residual 2.432e-08: : 6it [00:00, 44.51it/s]
# Current residual 3.354e-08: : 4it [00:00, 88.30it/s]
# Current residual 1.511e-07: : 4it [00:00, 76.43it/s]
# Current residual 2.987e-09: : 4it [00:00, 78.33it/s]
# Current residual 2.923e-07: : 3it [00:00, 92.54it/s]
# Current residual 1.587e-07: : 8it [00:00, 85.78it/s]
# Current residual 6.920e-08: : 3it [00:00, 75.85it/s]
# Current residual 1.445e-08: : 2it [00:00, 69.07it/s]
# Current residual 3.562e-08: : 2it [00:00, 66.69it/s]
# Current residual 4.236e-09: : 4it [00:00, 73.91it/s]
# Current residual 8.548e-08: : 8it [00:00, 66.66it/s]
# Current residual 2.701e-08: : 4it [00:00, 98.62it/s]
# Current residual 2.051e-08: : 2it [00:00, 89.77it/s]
# Current residual 2.011e-08: : 2it [00:00, 94.08it/s]
# Current residual 2.143e-07: : 4it [00:00, 83.77it/s]
# Current residual 1.072e-07: : 10it [00:00, 85.68it/s]
# Current residual 6.831e-07: : 6it [00:00, 51.05it/s]
# Current residual 1.695e-08: : 4it [00:00, 95.30it/s]
# Current residual 6.051e-08: : 3it [00:00, 98.35it/s]
# Current residual 1.030e-07: : 4it [00:00, 93.58it/s]
# Current residual 2.758e-07: : 8it [00:00, 88.86it/s]
# Current residual 2.810e-07: : 10it [00:00, 70.62it/s]
# Current residual 7.743e-07: : 7it [00:00, 87.12it/s]
# Current residual 2.131e-07: : 8it [00:00, 91.73it/s]
# Current residual 1.014e-08: : 6it [00:00, 48.63it/s]
# Current residual 4.968e-07: : 3it [00:00, 83.47it/s]
# Current residual 1.731e-10: : 3it [00:00, 66.11it/s]
# Current residual 6.074e-07: : 3it [00:00, 71.12it/s]
# Current residual 2.951e-08: : 5it [00:00, 76.07it/s]
# Current residual 2.637e-08: : 5it [00:00, 75.27it/s]
# Current residual 5.062e-07: : 3it [00:00, 28.83it/s]
# Current residual 1.018e-07: : 4it [00:00, 73.20it/s]
# Current residual 3.156e-07: : 3it [00:00, 72.51it/s]
# Current residual 4.730e-08: : 5it [00:00, 73.85it/s]
# Current residual 2.023e-07: : 4it [00:00, 73.51it/s]
# Current residual 4.762e-08: : 5it [00:00, 76.86it/s]
# Current residual 7.400e-07: : 3it [00:00, 51.19it/s]
# Current residual 1.191e-08: : 4it [00:00, 70.41it/s]
# Current residual 2.382e-09: : 4it [00:00, 48.02it/s]
# Current residual 3.098e-07: : 4it [00:00, 67.06it/s]
# Current residual 2.442e-08: : 6it [00:00, 40.69it/s]
# Current residual 1.093e-08: : 4it [00:00, 28.32it/s]
# Current residual 1.079e-07: : 4it [00:00, 68.21it/s]
# Current residual 1.390e-07: : 5it [00:00, 71.78it/s]
# Current residual 3.434e-08: : 5it [00:00, 73.34it/s]
# Current residual 3.441e-07: : 4it [00:00, 69.67it/s]
# Current residual 5.300e-08: : 5it [00:00, 35.04it/s]
# Current residual 9.918e-08: : 3it [00:00, 69.47it/s]
# Current residual 3.960e-07: : 3it [00:00, 43.89it/s]
# Current residual 5.511e-08: : 3it [00:00, 66.45it/s]
# Current residual 5.456e-08: : 5it [00:00, 44.25it/s]
# Current residual 3.319e-09: : 5it [00:00, 56.75it/s]
# Current residual 2.119e-09: : 4it [00:00, 30.31it/s]
# Current residual 1.575e-10: : 3it [00:00, 63.34it/s]
# Current residual 1.453e-08: : 5it [00:00, 68.06it/s]
# Current residual 3.002e-09: : 4it [00:00, 67.38it/s]
# Current residual 5.619e-08: : 3it [00:00, 68.42it/s]
# Current residual 2.307e-08: : 4it [00:00, 64.54it/s]
# Current residual 6.713e-08: : 4it [00:00, 27.76it/s]
# Current residual 4.776e-07: : 3it [00:00, 65.30it/s]
# Current residual 9.410e-07: : 4it [00:00, 59.65it/s]
# Current residual 3.728e-09: : 5it [00:00, 42.84it/s]
# Current residual 8.602e-08: : 3it [00:00, 56.36it/s]
# Current residual 3.220e-08: : 5it [00:00, 30.09it/s]
# Current residual 1.053e-07: : 4it [00:00, 37.89it/s]
# Current residual 3.303e-09: : 3it [00:00, 47.09it/s]
# Current residual 2.466e-08: : 4it [00:00, 62.58it/s]
# Current residual 6.765e-08: : 3it [00:00, 63.20it/s]
# Current residual 4.836e-08: : 4it [00:00, 51.05it/s]
# Current residual 2.581e-09: : 3it [00:00, 21.86it/s]
# Current residual 2.620e-08: : 3it [00:00, 48.96it/s]
# Current residual 2.777e-08: : 3it [00:00, 44.26it/s]
# Current residual 9.666e-07: : 4it [00:00, 67.95it/s]
# Current residual 5.047e-07: : 3it [00:00, 62.93it/s]
# Current residual 9.167e-07: : 4it [00:00, 72.75it/s]
# Current residual 2.803e-07: : 3it [00:00, 25.98it/s]
# Current residual 9.422e-07: : 4it [00:00, 44.36it/s]
# Current residual 6.968e-08: : 4it [00:00, 66.77it/s]
# Current residual 1.792e-10: : 3it [00:00, 50.08it/s]
# Current residual 4.678e-09: : 5it [00:00, 53.16it/s]
# Current residual 5.494e-09: : 5it [00:00, 62.04it/s]
# Current residual 3.205e-08: : 3it [00:00, 43.67it/s]
# Current residual 9.174e-08: : 5it [00:00, 52.05it/s]
# Current residual 4.178e-09: : 4it [00:00, 53.45it/s]
# Current residual 6.401e-09: : 5it [00:00, 55.52it/s]
# Current residual 3.816e-07: : 3it [00:00, 65.17it/s]
# Current residual 6.479e-09: : 5it [00:00, 24.96it/s]
# Current residual 6.441e-09: : 5it [00:00, 63.58it/s]
# Current residual 3.881e-07: : 3it [00:00, 53.71it/s]
# Current residual 7.535e-07: : 3it [00:00, 50.87it/s]
# Current residual 4.450e-07: : 3it [00:00, 38.23it/s]
# Current residual 5.044e-07: : 3it [00:00, 63.12it/s]
# Current residual 3.896e-09: : 4it [00:00, 31.81it/s]
# Current residual 5.131e-09: : 5it [00:00, 60.26it/s]
# Current residual 2.454e-08: : 4it [00:00, 60.51it/s]
# Current residual 2.703e-07: : 3it [00:00, 58.20it/s]
# Current residual 3.230e-08: : 4it [00:00, 57.20it/s]
# Current residual 7.334e-08: : 4it [00:00, 29.04it/s]
# Current residual 5.894e-08: : 3it [00:00, 54.15it/s]
# Current residual 2.185e-08: : 4it [00:00, 59.05it/s]
# Current residual 5.033e-07: : 3it [00:00, 51.62it/s]
# Current residual 8.965e-08: : 3it [00:00, 48.44it/s]
# Current residual 8.988e-08: : 3it [00:00, 54.74it/s]
# Current residual 1.906e-07: : 4it [00:00, 22.74it/s]
# Current residual 5.916e-07: : 4it [00:00, 50.76it/s]
# Current residual 1.690e-10: : 3it [00:00, 62.50it/s]
# Current residual 3.029e-08: : 4it [00:00, 61.27it/s]
# Current residual 6.178e-09: : 4it [00:00, 61.19it/s]
# Current residual 1.243e-09: : 4it [00:00, 63.28it/s]
# Current residual 2.002e-09: : 5it [00:00, 33.06it/s]
# Current residual 7.873e-08: : 3it [00:00, 62.19it/s]
# Current residual 4.606e-07: : 4it [00:00, 61.58it/s]
# Current residual 5.438e-08: : 3it [00:00, 65.66it/s]
# Current residual 2.610e-07: : 4it [00:00, 65.31it/s]
# Current residual 4.507e-07: : 4it [00:00, 62.84it/s]
# Current residual 6.927e-09: : 5it [00:00, 32.06it/s]
# Current residual 1.648e-09: : 4it [00:00, 63.44it/s]
# Current residual 2.003e-08: : 4it [00:00, 63.30it/s]
# Current residual 8.385e-07: : 4it [00:00, 64.58it/s]
# Current residual 4.570e-09: : 3it [00:00, 60.43it/s]
# Current residual 8.003e-09: : 4it [00:00, 31.22it/s]
# Current residual 4.548e-07: : 3it [00:00, 62.40it/s]
# Current residual 1.601e-08: : 4it [00:00, 62.65it/s]
# Current residual 5.012e-09: : 3it [00:00, 65.48it/s]
# Current residual 8.143e-08: : 3it [00:00, 64.97it/s]
# Current residual 4.049e-07: : 3it [00:00, 56.09it/s]
# Current residual 1.938e-07: : 3it [00:00, 60.49it/s]
# Current residual 5.201e-07: : 4it [00:00, 29.47it/s]
# Current residual 7.924e-07: : 4it [00:00, 62.57it/s]
# Current residual 1.543e-09: : 4it [00:00, 65.35it/s]
# Current residual 1.618e-08: : 4it [00:00, 61.96it/s]
# Current residual 4.192e-07: : 4it [00:00, 63.21it/s]
# Current residual 3.648e-07: : 3it [00:00, 26.28it/s]
# Current residual 2.769e-07: : 3it [00:00, 66.60it/s]
# Current residual 1.140e-08: : 5it [00:00, 45.93it/s]
# Current residual 7.435e-07: : 4it [00:00, 64.72it/s]
# Current residual 3.942e-08: : 3it [00:00, 64.71it/s]
# Current residual 2.151e-08: : 3it [00:00, 64.98it/s]
# Current residual 3.103e-07: : 4it [00:00, 64.57it/s]
# Current residual 3.982e-07: : 3it [00:00, 24.89it/s]
# Current residual 1.801e-10: : 3it [00:00, 66.10it/s]
# Current residual 1.957e-07: : 3it [00:00, 63.08it/s]
# Current residual 2.150e-08: : 4it [00:00, 65.66it/s]
# Current residual 5.040e-07: : 3it [00:00, 66.23it/s]
# Current residual 1.255e-09: : 4it [00:00, 57.68it/s]
# Current residual 9.726e-09: : 4it [00:00, 40.04it/s]
# Current residual 3.784e-09: : 4it [00:00, 49.46it/s]
# Current residual 3.556e-09: : 5it [00:00, 67.21it/s]
# Current residual 8.568e-09: : 4it [00:00, 64.27it/s]
# Current residual 3.585e-07: : 4it [00:00, 64.08it/s]
# Current residual 1.518e-07: : 4it [00:00, 28.18it/s]
# Current residual 8.677e-09: : 4it [00:00, 41.89it/s]
# Current residual 1.743e-10: : 3it [00:00, 66.79it/s]
# Current residual 2.226e-09: : 4it [00:00, 68.27it/s]
# Current residual 8.975e-08: : 3it [00:00, 66.74it/s]
# Current residual 6.288e-07: : 3it [00:00, 63.34it/s]
# Current residual 7.983e-07: : 3it [00:00, 63.92it/s]
# Current residual 4.424e-07: : 3it [00:00, 24.90it/s]
# Current residual 1.414e-07: : 3it [00:00, 62.47it/s]
# Current residual 6.600e-09: : 4it [00:00, 45.85it/s]
# Current residual 2.181e-07: : 4it [00:00, 58.46it/s]
# Current residual 8.105e-08: : 4it [00:00, 65.14it/s]
# Current residual 8.221e-08: : 3it [00:00, 62.56it/s]
# Current residual 9.757e-09: : 3it [00:00, 61.51it/s]
# Current residual 5.261e-07: : 4it [00:00, 50.82it/s]
# Current residual 6.381e-08: : 3it [00:00, 57.17it/s]
# Current residual 1.979e-09: : 5it [00:00, 53.26it/s]
# Current residual 2.425e-09: : 4it [00:00, 60.27it/s]
# Current residual 1.597e-07: : 4it [00:00, 42.21it/s]
# Current residual 5.034e-07: : 3it [00:00, 68.81it/s]
# Current residual 4.705e-09: : 4it [00:00, 29.28it/s]
# Current residual 5.831e-09: : 3it [00:00, 58.54it/s]
# Current residual 5.327e-07: : 4it [00:00, 58.25it/s]
# Current residual 3.692e-07: : 4it [00:00, 65.17it/s]
# Current residual 1.219e-07: : 3it [00:00, 63.01it/s]
# Current residual 1.652e-08: : 3it [00:00, 24.24it/s]
# Current residual 3.004e-08: : 3it [00:00, 68.50it/s]
# Current residual 4.192e-09: : 4it [00:00, 65.14it/s]
# Current residual 2.172e-09: : 4it [00:00, 69.51it/s]
# Current residual 1.575e-07: : 3it [00:00, 75.69it/s]
# Current residual 1.637e-07: : 3it [00:00, 69.00it/s]
# Current residual 7.739e-10: : 4it [00:00, 70.70it/s]
# Current residual 4.118e-07: : 4it [00:00, 30.46it/s]
# Current residual 3.089e-09: : 4it [00:00, 66.55it/s]
# Current residual 1.798e-10: : 3it [00:00, 34.41it/s]
# Current residual 1.332e-07: : 4it [00:00, 68.95it/s]
# Current residual 2.600e-07: : 4it [00:00, 72.44it/s]
# Current residual 2.746e-09: : 5it [00:00, 43.48it/s]
# Current residual 9.312e-08: : 4it [00:00, 52.72it/s]
# Current residual 2.212e-07: : 3it [00:00, 75.84it/s]
# Current residual 2.493e-07: : 3it [00:00, 71.84it/s]
# Current residual 5.039e-07: : 3it [00:00, 69.31it/s]
# Current residual 9.010e-10: : 4it [00:00, 49.14it/s]
# Current residual 6.606e-09: : 4it [00:00, 36.63it/s]
# Current residual 4.140e-07: : 3it [00:00, 52.37it/s]
# Current residual 4.158e-07: : 4it [00:00, 71.37it/s]
# Current residual 1.730e-07: : 4it [00:00, 70.20it/s]
# Current residual 3.862e-09: : 4it [00:00, 74.27it/s]
# Current residual 5.128e-07: : 4it [00:00, 52.39it/s]
# Current residual 3.123e-07: : 3it [00:00, 61.01it/s]
# Current residual 1.295e-07: : 4it [00:00, 51.86it/s]
# Current residual 1.478e-09: : 4it [00:00, 69.64it/s]
# Current residual 1.764e-10: : 3it [00:00, 70.94it/s]
# Current residual 1.813e-07: : 3it [00:00, 72.95it/s]
# Current residual 1.444e-07: : 3it [00:00, 74.40it/s]
# Current residual 1.954e-09: : 5it [00:00, 78.16it/s]
# Current residual 9.564e-08: : 3it [00:00, 22.28it/s]
# Current residual 2.701e-09: : 4it [00:00, 66.62it/s]
# Current residual 4.355e-07: : 3it [00:00, 70.10it/s]
# Current residual 5.035e-07: : 3it [00:00, 71.17it/s]
# Current residual 7.988e-07: : 3it [00:00, 72.78it/s]
# Current residual 1.534e-09: : 4it [00:00, 76.18it/s]
# Current residual 2.265e-07: : 4it [00:00, 75.21it/s]
# Current residual 9.594e-08: : 3it [00:00, 22.70it/s]
# Current residual 3.417e-07: : 4it [00:00, 67.49it/s]
# Current residual 7.307e-08: : 3it [00:00, 73.98it/s]
# Current residual 2.220e-09: : 4it [00:00, 76.79it/s]
# Current residual 2.910e-07: : 4it [00:00, 73.33it/s]
# Current residual 7.703e-09: : 3it [00:00, 54.11it/s]
# Current residual 4.837e-08: : 4it [00:00, 66.06it/s]
# Current residual 7.578e-10: : 4it [00:00, 40.35it/s]
# Current residual 5.268e-07: : 3it [00:00, 58.00it/s]
# Current residual 4.273e-08: : 4it [00:00, 71.61it/s]
# Current residual 1.063e-07: : 4it [00:00, 51.38it/s]
# Current residual 1.343e-08: : 3it [00:00, 63.23it/s]
# Current residual 8.384e-10: : 4it [00:00, 61.12it/s]
# Current residual 2.428e-09: : 5it [00:00, 31.74it/s]
# Current residual 1.499e-07: : 4it [00:00, 73.44it/s]
# Current residual 2.810e-07: : 3it [00:00, 51.78it/s]
# Current residual 2.081e-07: : 4it [00:00, 63.64it/s]
# Current residual 2.415e-07: : 4it [00:00, 70.68it/s]
# Current residual 2.768e-09: : 4it [00:00, 72.61it/s]
# Current residual 2.360e-07: : 4it [00:00, 29.72it/s]
# Current residual 1.793e-10: : 3it [00:00, 62.34it/s]
# Current residual 3.108e-08: : 4it [00:00, 66.58it/s]
# Current residual 4.192e-07: : 3it [00:00, 56.55it/s]
# Current residual 5.038e-07: : 3it [00:00, 66.75it/s]
# Current residual 4.449e-08: : 4it [00:00, 70.62it/s]
# Current residual 1.483e-07: : 3it [00:00, 77.20it/s]
# Current residual 1.777e-07: : 3it [00:00, 28.33it/s]
# Current residual 1.905e-07: : 3it [00:00, 70.03it/s]
# Current residual 1.261e-07: : 4it [00:00, 72.39it/s]
# Current residual 2.530e-08: : 3it [00:00, 74.00it/s]
# Current residual 9.774e-07: : 3it [00:00, 48.10it/s]
# Current residual 1.854e-09: : 4it [00:00, 74.16it/s]
# Current residual 2.032e-09: : 4it [00:00, 30.98it/s]
# Current residual 1.410e-09: : 4it [00:00, 71.00it/s]
# Current residual 1.366e-07: : 3it [00:00, 70.74it/s]
# Current residual 1.401e-08: : 3it [00:00, 76.94it/s]
# Current residual 1.086e-09: : 4it [00:00, 67.13it/s]
# Current residual 2.173e-08: : 4it [00:00, 63.87it/s]
# Current residual 5.459e-07: : 3it [00:00, 31.99it/s]
# Current residual 5.236e-10: : 4it [00:00, 49.39it/s]
# Current residual 1.634e-07: : 4it [00:00, 69.69it/s]
# Current residual 1.566e-07: : 3it [00:00, 71.96it/s]
# Current residual 8.877e-08: : 4it [00:00, 76.34it/s]
# Current residual 1.035e-07: : 3it [00:00, 48.22it/s]
# Current residual 9.009e-09: : 3it [00:00, 69.24it/s]
# Current residual 6.626e-10: : 4it [00:00, 34.56it/s]
# Current residual 1.077e-07: : 3it [00:00, 70.05it/s]
# Current residual 1.588e-08: : 3it [00:00, 72.85it/s]
# Current residual 7.898e-08: : 4it [00:00, 70.81it/s]
# Current residual 4.315e-07: : 3it [00:00, 74.52it/s]
# Current residual 1.381e-07: : 4it [00:00, 77.78it/s]
# Current residual 2.260e-07: : 4it [00:00, 28.85it/s]
# Current residual 1.773e-10: : 3it [00:00, 69.26it/s]
# Current residual 2.228e-08: : 4it [00:00, 71.02it/s]
# Current residual 5.035e-07: : 3it [00:00, 37.58it/s]
# Current residual 1.935e-09: : 5it [00:00, 46.09it/s]
# Current residual 8.048e-10: : 4it [00:00, 72.26it/s]
# Current residual 1.332e-09: : 4it [00:00, 33.45it/s]
# Current residual 2.051e-07: : 3it [00:00, 64.03it/s]
# Current residual 8.751e-07: : 3it [00:00, 69.88it/s]
# Current residual 1.056e-09: : 4it [00:00, 59.80it/s]
# Current residual 7.671e-08: : 3it [00:00, 68.64it/s]
# 100%|██████████| 10/10 [00:19<00:00,  1.94s/it]

# %%
fig=plot_function(real_u)
plt.title('laplace solution of the PDE')
plt.show()

# %%
'''for model,laplace_clone in zip(models,laplace_models):
    laplace_clone.setup_fit(f, real_u, 1e-5)
    target= np.concatenate(
        [
            model.g_vec,
            model.f_vec,
        ]
    )
    laplace_clone.target_values=target'''
PDESolverLaplace.joint_fit(laplace_models,f,real_u)

# %%
laplace_aggregate=partial(dumb_aggregate,models=laplace_models,width=width)
fig=plot_vectorized_function(laplace_aggregate,0.05)
plt.title('laplace solution of the PDE')
plt.show()

# %%
local_laplacian=partial(laplacian_aggregate,models=models,width=width)
fig=plot_vectorized_function(local_laplacian,0.05)
plt.title('Numerical solution of the PDE')
plt.show()

# %%
fig=plot_vectorized_function(models[1].laplacian,0.05)
plt.title('Numerical solution of the PDE')
plt.show()

# %%
local_laplacian=partial(laplacian_aggregate,models=models,width=width)
fig=plot_function(lambda x:-f(x)+real_u(x))
plt.title('Numerical solution of the PDE')
plt.show()

# %%
models[0].gauss_newton_solution['z']
# Out:
# array([-1.02090996, -0.70081468, -0.50063122,  0.0060033 , -0.28756736,
#        -0.67731608,  0.14797689, -0.0460115 , -0.86585361, -0.38398141,
#        -0.73108706, -0.00494593, -0.5026348 , -0.35679262, -0.80518675,
#         0.1174634 , -0.57522337, -0.7535536 , -0.66618209, -0.33872511,
#         0.17888431, -0.44644856, -0.36955264, -0.63152882, -0.00705201,
#         0.1109212 , -0.71314694, -0.92556393,  0.2203712 , -0.65083026,
#        -0.27069744, -0.88952602, -0.37039847, -0.83351411, -1.03262687,
#        -0.58925735, -0.05362747, -0.28944069, -0.47933985, -0.16125927,
#        -0.279297  , -0.88780049, -0.48412942, -0.45040705,  0.23273638,
#         0.05154062, -0.02888904, -0.55923189, -0.95693051, -0.53722054,
#        -0.09825237, -0.90307031,  0.0194878 ,  0.12000655, -0.96373423,
#        -0.26307572, -0.10532315, -0.36039126, -0.81823145, -1.01380275,
#        -0.3865864 , -0.22715831, -0.70148056, -0.73259355, -0.62506087,
#        -0.11947089,  0.02877858, -0.12810184, -0.20907494,  0.12774329,
#        -0.377968  , -0.23237964, -0.40387412, -0.4166512 , -0.09230548,
#         0.07895853, -0.06615527, -0.85118801, -0.66429748, -0.05508786,
#        -0.64890082, -1.01699662,  0.06447811, -0.19843435, -0.72437088,
#         0.00577135, -0.63675062, -0.29360303, -0.35727031, -0.13281607,
#        -0.12950153, -0.88959993, -0.64064155, -0.65978377, -0.75748845,
#        -0.50342093, -0.37833264, -0.38494053, -0.47653138, -0.16216679,
#         0.09152149, -0.83884325, -0.3348124 , -0.64704748, -0.40848883,
#        -0.22048864, -0.62561936, -0.9813787 , -0.80321579, -0.90746653,
#        -0.02516912,  0.0587064 ,  0.13324525, -0.49468446, -0.56015287,
#         0.17585191,  0.03110723, -0.03087533, -0.43345948, -0.03012244,
#        -0.91561518, -0.33203797, -0.90458745, -1.01788812, -0.75439345,
#        -0.39852051, -0.13562504, -0.44297504, -0.5457656 , -0.97849209,
#        -0.34711305, -0.94755576, -0.59098671, -0.27807625, -0.19799129,
#        -0.0747654 ,  0.30296513, -0.55108661,  0.19286829, -0.35054033,
#         0.17033007, -0.65307464,  0.02869436, -0.58404549, -0.87683114,
#        -0.73946604, -0.53036368, -0.9801748 , -0.54900228, -0.20676913,
#        -0.59172439, -0.05922226, -0.85961299, -0.4352073 , -0.51614365,
#        -0.04402814, -0.16790847, -0.57685755, -0.17447599, -0.98646306,
#        -0.83996526, -0.51398779, -0.15310071, -0.33649414, -0.49236303,
#        -0.78605329, -0.94937766, -0.25938939, -0.02256309, -0.46935759,
#        -0.59562226,  0.0792763 , -0.35400322, -0.22625573, -0.43159247,
#        -0.16522356, -0.93229452, -0.66380064, -0.32914686, -0.61567511,
#         0.07773988,  0.03221822, -0.47078708, -0.12028257, -0.30083231,
#         0.08751694, -0.15096832, -0.39931827, -0.48463795, -0.4347371 ,
#        -0.35964854, -0.77996992,  0.15439593, -0.65212317, -0.98104943,
#        -0.64865905, -0.12173396, -0.34819751, -0.49105086, -0.38723976,
#         0.0816905 , -0.7755365 , -0.16989468, -0.94846473, -0.16480288,
#        -0.39422873,  0.22628025, -0.77750282, -0.18591236, -0.22004169,
#        -0.81737041, -0.14777368, -0.86712098, -0.45150845, -0.7791872 ,
#        -0.58476273, -0.03067439, -0.67631244, -0.25383197,  0.08942372,
#         0.0081917 , -0.82480007, -0.55159598,  0.15755333, -0.39460363,
#        -0.85435139, -0.79166878,  0.276421  , -0.81476966, -0.38875541,
#        -0.28806827, -0.39687656, -0.64535225, -0.95278285, -0.25000185,
#        -0.47905717, -0.22846945, -0.21967761, -0.06241825, -0.51591017,
#        -0.54964523,  0.09664344, -0.55303813, -0.0310663 , -0.25039612,
#        -0.31797226, -0.68085524, -0.76636857, -0.34661727, -0.2180612 ,
#        -0.60562608, -0.43772101, -0.31399497, -0.58820908, -0.84342896,
#        -0.40872212, -0.75600106, -0.15549104,  0.08137912, -0.13792894,
#        -0.53895918, -0.4107987 , -0.36236716, -0.26945492, -0.49388232,
#        -0.29369802, -0.15124204, -0.54275364, -0.20810189, -0.71160088,
#        -0.04296188, -0.86538123, -0.74259155, -0.45988876, -0.3957195 ,
#        -0.78801577, -0.16962516, -0.72715389, -0.36990805, -0.41268561,
#         0.05671912, -0.73795435, -0.17753965, -0.38514602, -0.83292007,
#        -0.73924564, -0.39258682,  0.05289134, -0.44760792, -0.69997304,
#        -0.60760068, -0.28024336, -0.66164086, -0.78334696, -0.19200871,
#        -0.04729741,  0.12720888, -0.22254565, -0.42219956, -0.9622986 ,
#        -0.72613456, -1.01260024, -0.81425069,  0.22103444, -0.46119622,
#        -0.36613586, -0.63198347, -0.76106328,  0.28558477, -0.06591874,
#        -0.18714284, -0.30972395, -0.39623268, -0.71546341, -0.01741817,
#        -0.33031765,  0.12564955, -0.28084581, -0.19436194, -0.87837317,
#        -0.18431367, -0.64422563, -0.54040459, -0.93879796, -0.23134087,
#        -0.25394663, -0.31281313, -0.27438389, -0.24879936, -0.27349012,
#        -0.15859167, -0.57314671,  0.22143866, -0.04190174, -0.149235  ,
#        -0.75457247, -0.45091033, -0.77417505, -0.42757998, -0.72623736,
#        -0.30895913, -0.45866059, -0.09017976, -0.23986003, -0.32643995,
#        -0.33705149, -0.42247118, -0.07058004, -0.09789259, -0.62132021,
#         0.02023564, -0.00983667, -0.51209043, -0.28554469, -0.03485407,
#        -0.56764124, -0.169302  , -0.15089482, -0.03005162, -0.10369612,
#        -0.29163876, -0.64521343, -0.44006645, -0.46082801, -0.89677377,
#        -0.47974731, -0.12002474, -0.20425258, -0.06804036, -0.5448867 ,
#        -0.68068484,  0.15058774, -0.94456725, -0.68435989, -0.42665543,
#        -0.44376575, -0.83400032,  0.01796476, -0.6951377 , -1.03141401,
#        -0.02799245, -0.86896019, -0.93024778, -0.34319246, -0.18733799,
#        -0.2699803 , -0.52961207, -0.32384497, -0.98528181,  0.04713998,
#        -0.32290521, -0.44658768, -0.07295193, -0.57682118, -0.9204423 ,
#        -0.67455363, -0.58058243, -0.67956645, -0.22986541, -0.57918343])

# %%
PDESolver.joint_fit_boundaries(models)

# %%
fig=plot_vectorized_function(models[2],0.05)
plt.title('Numerical solution of the PDE')
plt.show()

# %%
models[0].shared_value
# Out:
# {model 1: array([ 0.19267795,  0.34950197, -0.19764892,  0.14107846, -0.04897912,
#          0.22403403,  0.1888367 , -0.02466672,  0.15748017,  0.30619904,
#         -0.01409558,  0.33982522,  0.29192433,  0.1207835 , -0.14093757,
#          0.16131341, -0.00986539,  0.24363674, -0.04321884, -0.14790496,
#         -0.02230466,  0.24156295, -0.02255831, -0.10155741,  0.06506665,
#          0.23383927,  0.0665013 , -0.02005332,  0.23483127, -0.10765888,
#         -0.17061436, -0.12415496,  0.0415318 ,  0.20684492,  0.38481418,
#         -0.1999913 ,  0.06582139,  0.35166897,  0.02675643, -0.11045025]),
#  model 5: array([-0.34540483, -0.39081639,  0.23841273, -0.28764097, -0.1848833 ,
#          0.14696734,  0.25176826,  0.27025045,  0.35530739,  0.30283593,
#          0.29730195, -0.13190624, -0.2695244 ,  0.12713832,  0.22865762,
#         -0.33146419, -0.02088622,  0.02066748,  0.24731948,  0.3205664 ,
#          0.39354017,  0.23128657,  0.05305658,  0.27822562, -0.16393196,
#          0.08193238, -0.41833241,  0.30755637,  0.2102053 ,  0.26212038,
#          0.08011959, -0.32429348, -0.01781473, -0.34894729,  0.33677103,
#         -0.30939789,  0.10699652, -0.28855027,  0.36383943, -0.20847021])}

# %%
model0=PDESolver(
        X_int=make_points_inside(2000),
        X_boundary=make_points_boundary(500),
        sigma=sigma,
        name=f'model 0')
model0.fit_interior(f,real_u,tau,dtau,use_shared=False,nugget=1e-5)
# Out:
# Current residual 4.629e-09: : 6it [00:17,  2.97s/it]

# %%
model0.a = np.concatenate(
    [
        model0.gauss_newton_solution["z"],
        model0.g_vec,
        model0.gauss_newton_solution["z_lap"],
    ]
)
model0.coeff = model0.K_inv @ model0.a

# %%
fig=plot_vectorized_function(model0,0.05)
plt.title('Numerical solution of the PDE')
plt.show()
